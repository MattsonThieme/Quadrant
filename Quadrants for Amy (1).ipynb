# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rand

#Define radius and angle
r = np.arange(0,5,0.0001)
a = np.arange(0, np.pi/2 ,(np.pi/100000))#[:-1]
print(len(r))
print(len(a))
#x = r * np.cos(a)
#y = r * np.sin(a)

#Generate random integer list and zip with radii and angles
samp=50000
q = rand.sample(range(samp),samp)
qrzip = zip(r,q)
u = rand.sample(range(samp),samp)
uazip = zip(a,u)

#Turn tuples back into list
qr = list(qrzip)
ua = list(uazip)

# Sort with lamda function
qr.sort(key=lambda x: x[1])
ua.sort(key=lambda x: x[1])

#Form lists of radii and angles in random order
qrr = [qrr[0] for qrr in qr]
uaa = [uaa[0] for uaa in ua]

#Define variables
cos = qrr*np.cos(uaa)
sin = qrr*np.sin(uaa)

# Function x**(1/2)
def forward(x):
    return x**(1/2)


def inverse(x):
    return x**2

#plt.plot(cos, sin,'g,')
#plt.xlim(0, 5)
#plt.ylim(0, 5)
#plt.gca().set_aspect('equal', adjustable='box')
#plt.draw()

fig, axs = plt.subplots(1,1, figsize=(6, 8),
                        constrained_layout=True)
#ax = axs[0]
axs.plot(cos,sin,'g,')
axs.set_yscale('function', functions=(forward, inverse))

plt.show()
# Out:
# 50000
# 50001
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-d234c3dec9fe> in <module>
#      77 #ax = axs[0]
#      78 axs.plot(cos,sin,'g,')
# ---> 79 axs.set_yscale('function', functions=(forward, inverse))
#      80
#      81 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in set_yscale(self, value, **kwargs)
#    3702         g = self.get_shared_y_axes()
#    3703         for ax in g.get_siblings(self):
# -> 3704             ax.yaxis._set_scale(value, **kwargs)
#    3705             ax._update_transScale()
#    3706             ax.stale = True
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _set_scale(self, value, **kwargs)
#     765
#     766     def _set_scale(self, value, **kwargs):
# --> 767         self._scale = mscale.scale_factory(value, self, **kwargs)
#     768         self._scale.set_default_locators_and_formatters(self)
#     769
#
# ~\Anaconda3\lib\site-packages\matplotlib\scale.py in scale_factory(scale, axis, **kwargs)
#     565
#     566     if scale not in _scale_mapping:
# --> 567         raise ValueError("Unknown scale type '%s'" % scale)
#     568
#     569     return _scale_mapping[scale](axis, **kwargs)
#
# ValueError: Unknown scale type 'function'
